# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
amazon = pd.read_excel("datasets\Book_products.xlsx", 
                       sheet_name="amazon_products",
                      na_filter=True)

barnes = pd.read_excel("datasets\Book_products.xlsx", 
                       sheet_name="barnes_noble_products",
                      na_filter=True)

ebay = pd.read_excel("datasets\Book_products.xlsx", 
                       sheet_name="ebay_products",
                      na_filter=True)

pd_amazon = pd.pivot_table(amazon, values="Price", index="Book Name").sort_values("Price", ascending=False)

pd_barnes = pd.pivot_table(barnes, values="Price", index="Book Name").sort_values("Price", ascending=False)

pd_ebay = pd.pivot_table(ebay, values="price_new", index = "Book Name").sort_values("price_new", ascending=False)

# %%
pd_amazon.head()
# Out:
#                                                     Price
# Book Name
# Harry Potter Paperback Box Set (Books 1-7)          34.68
# Just Tyrus: A Memoir                                32.49
# Berserk Deluxe Volume 1                             29.99
# This Will Not Pass: Trump, Biden, and the Battl...  24.99
# The Palace Papers: Inside the House of Windsor-...  22.46

# %%
sns.set()
plt.rcParams["figure.figsize"] = [20, 10]
ax = sns.barplot(x=pd_amazon.index, y="Price", data=pd_amazon)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.title("Amazon Book Price")

plt.show()

# %%
plt.hist(pd_amazon, bins=8)
plt.xlabel("price")
plt.ylabel("amount")
plt.title("Amazon Histogram by Price Interval")
# Out:
# Text(0.5, 1.0, 'Amazon Histogram by Price Interval')
